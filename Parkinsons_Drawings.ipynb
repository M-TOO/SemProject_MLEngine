# %% [markdown]
# <a href="https://colab.research.google.com/github/M-TOO/SemProject_MLEngine/blob/main/Parkinsons_Drawings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/parkinsons.data")

print(f"No of rows: {df.shape[0]}")
print(f"No of columns: {df.shape[1]}")

print(df.dtypes)

if df.isnull() is True:
  print("Missing values present")
else:
  print("No missing values")

df1 = df.head(15)
df2 = df.tail(20)

df_sample = pd.concat([df1, df2])
print(df_sample)
# Out:
# No of rows: 195
# No of columns: 24
# name                 object
# MDVP:Fo(Hz)         float64
# MDVP:Fhi(Hz)        float64
# MDVP:Flo(Hz)        float64
# MDVP:Jitter(%)      float64
# MDVP:Jitter(Abs)    float64
# MDVP:RAP            float64
# MDVP:PPQ            float64
# Jitter:DDP          float64
# MDVP:Shimmer        float64
# MDVP:Shimmer(dB)    float64
# Shimmer:APQ3        float64
# Shimmer:APQ5        float64
# MDVP:APQ            float64
# Shimmer:DDA         float64
# NHR                 float64
# HNR                 float64
# status                int64
# RPDE                float64
# DFA                 float64
# spread1             float64
# spread2             float64
# D2                  float64
# PPE                 float64
# dtype: object
# No missing values
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0    phon_R01_S01_1      119.992       157.302        74.997         0.00784
# ...
